# %% [markdown]
# # Importing functions from categorical_target_eda module

# %%
## categorical_target_eda module is saved as categorical_target_eda.py in this repo
## categorical_target_eda.py stores all the functions I'll be using 

from categorical_target_eda import *

# %% [markdown]
# # Saving the DF we make with this module as 'df'

# %%
## casting df as the return of deploy_categorical_target_EDA() so user may 
## continue cleaning and visualizing in a more streamlined manner 

# EXAMPLE Fetal Health

df = deploy_categorical_target_EDA()
# Out:
# "What CSV file would you like to use? Make sure it's in this repository!"
# Filename: fetal_health.csv
# ['baseline value',
#  'accelerations',
#  'fetal_movement',
#  'uterine_contractions',
#  'light_decelerations',
#  'severe_decelerations',
#  'prolongued_decelerations',
#  'abnormal_short_term_variability',
#  'mean_value_of_short_term_variability',
#  'percentage_of_time_with_abnormal_long_term_variability',
#  'mean_value_of_long_term_variability',
#  'histogram_width',
#  'histogram_min',
#  'histogram_max',
#  'histogram_number_of_peaks',
#  'histogram_number_of_zeroes',
#  'histogram_mode',
#  'histogram_mean',
#  'histogram_median',
#  'histogram_variance',
#  'histogram_tendency',
#  'fetal_health']
# Would you like to reformat the columns from 'Title Case' to 'snake_case':  y/n n
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
# ...

# %%
## showing the first five rows of the DF we've been working with 

df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
df.drop(columns = 'baseline value', inplace = True)
# Out:
#       accelerations  fetal_movement  uterine_contractions  \
# 0             0.000           0.000                 0.000
# 1             0.006           0.000                 0.006
# 2             0.003           0.000                 0.008
# 3             0.003           0.000                 0.008
# 4             0.007           0.000                 0.008
# ...             ...             ...                   ...
# 2121          0.000           0.000                 0.007
# 2122          0.001           0.000                 0.007
# 2123          0.001           0.000                 0.007
# 2124          0.001           0.000                 0.006
# 2125          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                   0.000                   0.0                       0.0
# 1                   0.003                   0.0                       0.0
# ...

# %% [markdown]
# # Other Examples

# %%
# EXAMPLE NYPD Hate Crimes 

df = deploy_categorical_target_EDA()
# Out:
# "What CSV file would you like to use? Make sure it's in this repository!"
# Filename: hate_crimes.csv
# ['Full Complaint ID',
#  'Complaint Year Number',
#  'Month Number',
#  'Record Create Date',
#  'Complaint Precinct Code',
#  'Patrol Borough Name',
#  'County',
#  'Law Code Category Description',
#  'Offense Description',
#  'PD Code Description',
#  'Bias Motive Description',
#  'Offense Category',
#  'Arrest Date',
#  'Arrest Id']
# Would you like to reformat the columns from 'Title Case' to 'snake_case':  y/n y
# 'columns reformatted'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1809 entries, 0 to 1808
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   full_complaint_id              1809 non-null   int64
#  1   complaint_year_number          1809 non-null   int64
#  2   month_number                   1809 non-null   int64
# ...

# %%
# EXAMPLE Seattle Housing Data

df = deploy_categorical_target_EDA()
# Out:
# "What CSV file would you like to use? Make sure it's in this repository!"
# Filename: kc_house_data.csv
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']
# Would you like to reformat the columns from 'Title Case' to 'snake_case':  y/n n
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
# ...
